# %% [markdown]
# # Template

# %%
import os 
try:
    os.chdir("../../plot")
except:
    pass
print(os.getcwd())
# Out:
# c:\users\beomj\src\plot\plot

# %%
import json 
from scalar.lineplot import *

# %%
with open("config.json")  as jsonfile:
    cfg = json.load(jsonfile)

cfg['data'] =  pd.read_csv("C:\\Users\\beomj\\src\\plot\\make_data\\data\\sequence.csv")
cfg['x'] =  cfg['data'].index
cfg['y'] = "x"

# lineplot(cfg)

# %%
cfg['plt_info']['title']="Beta"
cfg['plt_info']['ylabel']="Beta"

lineplot(cfg)
plt.show()

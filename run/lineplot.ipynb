# %% [markdown]
# # Template

# %%
import os 
try:
    os.chdir("../../plot")
except:
    pass
print(os.getcwd())
# Out:
# c:\Users\beomj\src\plot

# %%
import json 
from scalar.lineplot import *

# %%
with open("config.json")  as jsonfile:
    cfg = json.load(jsonfile)

# cfg['data'] =  pd.read_csv("c:/users/beomj/download/annealing.csv")
# cfg['x'] =  cfg['data'].index
# cfg['y'] = "beta"

# lineplot(cfg)

# %%
cfg['plt_info']['ylabel']='loss'

cfg['data'] =  pd.read_csv("c:/users/beomj/downloads/"+'run-ANNEALING_V1-tag-Cross-Entropy.csv')
cfg['x'] = "Step"
cfg['y'] = "Value"

lineplot(cfg)
cfg['new_figure']=0
cfg['data'] =  pd.read_csv("c:/users/beomj/downloads/"+'run-ANNEALING_V2-tag-Cross-Entropy.csv')
cfg['x'] = "Step"
cfg['y'] = "Value"

lineplot(cfg)
cfg['data'] =  pd.read_csv("c:/users/beomj/downloads/"+'run-ANNEALING_V3-tag-Cross-Entropy.csv')
cfg['x'] = "Step"
cfg['y'] = "Value"

lineplot(cfg)
cfg['data'] =  pd.read_csv("c:/users/beomj/downloads/"+'run-BART_BASE-tag-Loss_train_ce.csv')
cfg['x'] = "Step"
cfg['y'] = "Value"

lineplot(cfg)
plt.legend(["V1", "V2", "V3", "BART"])
plt.show()
